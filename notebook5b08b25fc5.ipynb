# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/visdrone.yaml
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999939_00000_d_0000208.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999954_00000_d_0000089.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/0000231_01500_d_0000004.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999983_00000_d_0000081.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999946_00000_d_0000036.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999983_00000_d_0000131.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/9999936_00000_d_0000100.jpg
# /kaggle/input/visdrone-dataset/VisDrone_Dataset/VisDrone2019-DET-test-challenge/images/0000231_01000_d_0000003.jpg
# ...

# %%
# !git clone https://github.com/qiqiya023/ultralytics-qi.git
# Out:
# Cloning into 'ultralytics-qi'...
# remote: Enumerating objects: 45516, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 45516 (delta 17), reused 7 (delta 7), pack-reused 45476 (from 3)
# Receiving objects: 100% (45516/45516), 27.29 MiB | 21.30 MiB/s, done.
# Resolving deltas: 100% (33513/33513), done.

# %%
# !pip install ultralytics==8.3.234 --no-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# !mv yolo11n.pt /kaggle/working/ultralytics-qi

# %%
# !cd ultralytics-qi
# !yolo detect train model=yolo11n.pt data=./ultralytics/cfg/datasets/VisDrone.yaml epochs=50
# Out:
# ...
# Ultralytics 8.3.234 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
